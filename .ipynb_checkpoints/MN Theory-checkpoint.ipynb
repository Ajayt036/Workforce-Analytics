# %% [markdown]
# # Human Resource Analytics
#
# Source: https://www.coursera.org/learn/human-resources-analytics
#
#
# #### Week 1. HR Metric
#
# 1.Defination: Workforce analytics is the approach of measuring behaviors of people (candidates, employees) and analyzing them to improve people and business performance.
#
# 2.Result: Business and employees both benefit.
#
# 3.HR Analytics has three stages: Repoting | Analsysi | Prediction
#
# 4.Questions to keep in Mind before slecting measures:
# <img src="1.png" width="500" height="440">
#
# 5.What makes a good metric?
# - Any metric which adds on the data story and provides valuables info, is a good metric
# <img src="Screen Shot 2022-05-26 at 12.12.23 PM.png" width="500" height="440">

# %% [markdown]
# ___________________________________________________________________________________________________________________

# %% [markdown]
# # Power BI
